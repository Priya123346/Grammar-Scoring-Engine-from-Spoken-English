# %%
import torchaudio
waveform,sr=torchaudio.load("C:\Users\kotag\OneDrive\Desktop\GrammarScoreGenerator\data\dataset\audios_train\audio_2.wav")
print(f"Sample Rate: {sr}")
print(f"Waveform Shape: {waveform.shape}")
